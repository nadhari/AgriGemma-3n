# %% [markdown]
# # AgriGemma-3n: Fine-Tuning Gemma For On-Device Agricultural Intelligence

# %% [markdown]
# ## Dataset Download
#
# The **Crop Disease Domain Multimodal (CDDM)** dataset is a comprehensive agricultural AI resource containing:
#
# - **137,000 crop disease images** paired with **1 million question-answer pairs**
# - Covers **16 crop categories** and **60 disease types**
# - Includes detailed Q&A conversations about disease identification, symptoms, causes, prevention, and treatment strategies
# - Designed for training multimodal AI models that can provide practical farming advice
#
# **Paper**: [A Multimodal Benchmark Dataset and Model for Crop Disease Diagnosis](https://arxiv.org/abs/2503.06973)
# **Dataset**: Available at [GitHub](https://github.com/UnicomAI/UnicomBenchmark/tree/main/CDDMBench)
#
# This dataset is particularly well-suited for the fine-tuning of Gemma 3n as it combines visual disease identification with comprehensive agricultural knowledge that can help farmers make informed decisions in the field.

# %%
# !pip install -q --upgrade gdown

# %%
import gdown

# Drive file ID (the long string after `/d/` in the link)
file_id = "1kfB3zkittoef4BasOhwvAb8Cb66EPXst"

# This will create dataset.zip in the working directory
gdown.download(id=file_id, output="dataset.zip", quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1kfB3zkittoef4BasOhwvAb8Cb66EPXst
# From (redirected): https://drive.google.com/uc?id=1kfB3zkittoef4BasOhwvAb8Cb66EPXst&confirm=t&uuid=a030277e-09c7-4dbf-a133-abf6bbdf8ab5
# To: /content/dataset.zip
# 100%|██████████| 2.77G/2.77G [00:22<00:00, 122MB/s]
# 'dataset.zip'

# %%
import os, zipfile

# Make sure the destination exists
os.makedirs("dataset", exist_ok=True)

# Extract
with zipfile.ZipFile("dataset.zip", "r") as z:
    z.extractall("dataset")

print("Done! Extracted to ./dataset")

# %%
import pathlib, itertools
first_few = itertools.islice(pathlib.Path("dataset").rglob("*"), 20)
for p in first_few:
    print(p.relative_to("dataset"))

# %%
# !mkdir -p dataset/VQA

# %%
# Raw file URL (swap github.com → raw.githubusercontent.com)
zip_url = (
    "https://raw.githubusercontent.com/"
    "UnicomAI/UnicomBenchmark/main/"
    "CDDMBench/dataset/VQA/Crop_Disease_train_qwenvl.zip"
)

# Grab it with wget (--show-progress so you see a progress bar)
# !wget -q --show-progress -O Crop_Disease_train_qwenvl.zip "$zip_url"

# %%
import zipfile, os

os.makedirs("dataset/VQA", exist_ok=True)
with zipfile.ZipFile("Crop_Disease_train_qwenvl.zip") as z:
    z.extractall("dataset/VQA")

print("Done! Extracted to ./dataset/VQA")

# %%
# !mkdir -p dataset/VQA/test_dataset

# %%
# Raw URL (github.com ➜ raw.githubusercontent.com)
zip_url = (
    "https://raw.githubusercontent.com/"
    "UnicomAI/UnicomBenchmark/main/"
    "CDDMBench/dataset/VQA/test_dataset.zip"
)

# Download with a progress bar
# !wget -q --show-progress -O test_dataset.zip "$zip_url"
# Out:
# test_dataset.zip    100%[===================>]  93.04K  --.-KB/s    in 0.02s

# %%
first20 = itertools.islice(pathlib.Path("dataset/VQA").rglob("*"), 20)
for p in first20:
    print(p.relative_to("dataset/VQA"))
# Out:
# test_dataset
# Crop_Disease_train_qwenvl.json
# test_dataset/disease_knowledge.json
# test_dataset/disease_diagnosis.json

# %%
from pathlib import Path
import json, itertools, collections, random, pprint
img_root = Path("dataset/images")        # <- change if needed

# List the first two crop/disease folders
for p in itertools.islice(img_root.iterdir(), 2):
    print("📂", p.name)
# Out:
# 📂 Rice,Leaf Blight
# 📂 Rice,Leaf Smut

# %%
img_exts = {".jpg", ".jpeg", ".png", ".bmp", ".webp"}

all_imgs = [p for p in img_root.rglob("*") if p.suffix.lower() in img_exts]
print(f"Total images found: {len(all_imgs):,}")

# Count by crop,disease folder (folder name is "Crop,Disease")
per_class = collections.Counter(p.parent.name for p in all_imgs)
print("\nTop 10 classes by image count:")
for cls, n in per_class.most_common(10):
    crop, disease = cls.split(",", 1)
    print(f"  {crop:12} | {disease:25} : {n:5}")
# Out:
# Total images found: 137,007
#
# Top 10 classes by image count:
#   Tomato       | Yellow Leaf Curl Virus    :  7967
#   Apple        | Leaf Rust                 :  7554
#   Apple        | Healthy                   :  6269
#   Tomato       | Late Blight               :  5923
#   Tomato       | Bacterial Spot            :  5784
#   Apple        | Brown Spot                :  5655
#   Tomato       | Septoria Leaf Spot        :  5545
#   Orange       | Citrus Greening           :  5507
#   Tomato       | Healthy                   :  5358
#   Apple        | Alternaria Blotch         :  5343

# %%
def sample_images(n=20000, seed=42):
    random.seed(seed)
    return random.sample(all_imgs, n)

# Example usage:
subset = sample_images()
print("Subset example:", subset[:3])
# Out:
# Subset example: [PosixPath('dataset/images/Apple,Black Rot/plant_75026.jpg'), PosixPath('dataset/images/Tomato,Early Blight/plant_18950.jpg'), PosixPath('dataset/images/Tomato,Healthy/plant_23392.jpg')]

# %%
vqa_root = Path("dataset/VQA")

json_files = {
    "train":  vqa_root / "Crop_Disease_train_qwenvl.json",
    "diag":   vqa_root / "test_dataset/disease_diagnosis.json",
    "know":   vqa_root / "test_dataset/disease_knowledge.json",
}

for tag, jf in json_files.items():
    with open(jf, "r", encoding="utf-8") as f:
        data = json.load(f)
    print(f"\n=== {tag.upper()} ===  {jf.name}")
    # Handle both list-style and dict-with-`data` formats
    records = data if isinstance(data, list) else data.get("data", [])
    print(f"Records: {len(records):,}")
    pprint.pprint(records[0], width=120, compact=True)
# Out:
# === TRAIN ===  Crop_Disease_train_qwenvl.json
# Records: 145,261
# {'conversations': [{'from': 'user',
#                     'value': 'Picture 1: <img>/dataset/images/Apple,Alternaria Blotch/plant_74609.jpg</img>\n'
#                              'What is the content of this picture?'},
#                    {'from': 'assistant', 'value': 'This image shows an apple leaf affected by Alternaria Blotch.'},
#                    {'from': 'user', 'value': 'Is this crop diseased? '},
#                    {'from': 'assistant', 'value': 'Yes, this apple leaf is afflicted with Alternaria Blotch.'},
#                    {'from': 'user', 'value': 'What disease does this apple leaf have? '},
#                    {'from': 'assistant', 'value': 'This apple leaf is affected by Alternaria Blotch.'},
#                    {'from': 'user', 'value': 'Is this leaf from a pear tree? '},
#                    {'from': 'assistant', 'value': 'No, this is an apple leaf.'},
#                    {'from': 'user', 'value': 'Is this an apple leaf or an orange leaf? '},
#                    {'from': 'assistant', 'value': 'This is an apple leaf.'},
#                    {'from': 'user', 'value': "What plant's leaf is this? "},
#                    {'from': 'assistant', 'value': 'This is an apple leaf.'},
#                    {'from': 'user', 'value': 'Is this grape leaf healthy? '},
#                    {'from': 'assistant',
#                     'value': "This is not a grape leaf; it's an apple leaf afflicted with Alternaria Blotch."},
#                    {'from': 'user', 'value': 'Has this leaf contracted Cedar Apple Rust? '},
#                    {'from': 'assistant', 'value': 'No, this apple leaf has Alternaria Blotch.'}],
#  'id': 'conv_34293_0'}
#
# === DIAG ===  disease_diagnosis.json
# Records: 3,963
# {'answer': 'No, this is an apple leaf.',
#  'image': '/dataset/images/Apple,Leaf Rust/plant_98574.jpg',
#  'question': 'Is this leaf from a grapevine? ',
#  'question_id': 'test_conv_0001'}
#
# === KNOW ===  disease_knowledge.json
# Records: 20
# {'answer': '(1) Select 2-3 locally resistant varieties, such as Zao 58, Xiangzaoxian 3, 21, 22, 86-44, 87-156, Wandao '
#            '61, Ganzhao 39, 42, 41, Boyouzan 19, Zhongyouzao 81, Zhusi 2, Peiliangyou 288, Huaxianzhan, and Shanyou 77 '
#            'for early rice. For mid-season rice: Qidaozhan 1, Qixiuzhan 3, Peizashanqing, Sanpeizhan 1, Dianyinlujing '
#            '1, Ningjing 17, Ningnuo 4, Yangfuxian 2, Shengyou 2, Yangdao 2, 4, Dongxun 101, Dongnong 419, Qiyou 7, Jia '
#            '45, Xiushui 1067, Wandao 28, 32, 34, 36, 59, Shanyou 89, Teyou 689, Shanyou 397, Shanyouduoxi 1, Mancang '
#            '515, Quannong 3, Jinyou 63, Shanyouduoxi 1. For late rice: Xiushui 644, Yuanjing 4, Jin 308, Jingdaoxuan '
#            '1, Jijin 15, Huajing 45, Liao 244, Shen 9017, Gangyou 22, Bijing 37, Dianzhajing 2, Gangyou 2, Dianxian '
#            '13, 14, 40, Ningjing 15, 16. For drought-resistant varieties, choose Lin 3, Lin 5, Jing 31119, China 91. '
#            'For dry direct seeding, use Zhengzhou Early Jing, Zhonghua 8.\n'
#            '(2) Use disease-free fields for seed collection, treat infected straw, and eliminate pathogen sources. Use '
#            'soil disinfectants.\n'
#            '(3) Seed treatment: Soak seeds in 56℃ hot water for 5 minutes. Use 10% 401 antibacterial agent 1000 times '
#            'solution or 80% 402 antibacterial agent (pyrimidine nucleoside antibiotics) 2000 times solution, or 70% '
#            'methyl thiophanate 1000 times solution for 2 days. Alternatively, use 1% lime water for 6 days at 10-15℃, '
#            'or 1-2 days at 20-25℃, with lime water 15cm above the seeds. Let stand, rinse 3-4 times with clean water. '
#            'Soak seeds in 2% formalin for 20-30 minutes, then cover with a film for 3 hours.\n'
#            '(4) Use disease-free fields for seed collection, treat infected straw, and eliminate pathogen sources. Use '
#            'soil disinfectants.\n'
#            '(5) Strengthen fertilizer and water management. Scientific management of fertilizer and water can improve '
#            'environmental conditions, control pathogen reproduction and infection, promote healthy rice growth, and '
#            'enhance disease resistance for stable and high yields. Apply nitrogen, phosphorus, and potassium in '
#            'balance, combining base fertilizer, organic fertilizer, and chemical fertilizer, with appropriate use of '
#            'silicon fertilizers (e.g., plant ash, slag, kiln ash potassium fertilizer). Apply sufficient potassium '
#            'fertilizer, early topdressing, and appropriate mid-term fertilization based on crop and field conditions. '
#            'Mixed application of silicon and magnesium fertilizers can significantly reduce disease incidence. Apply '
#            'appropriate amounts of green manure, lime to promote decomposition, and neutralize acidity. In cold '
#            'immersion fields, increase phosphate fertilizer application.\n'
#            '(6) Rotate fungicides due to the unique resistance of rice blast pathogen. Common fungicides like '
#            'Jinggangmycin, Chunlei mycin, tricyclazole, methyl thiophanate, blastil, and Fuji No.1 should be '
#            'alternated. For prevention and early disease: spray diluted 800-1200 times. For mid to late disease: spray '
#            'diluted 800-1000 times. For severe cases: spray 20% tricyclazole 500 times solution, followed by specific '
#            'fungicides like Menshen 800 times solution after 7 days. Use tebuconazole for leaf blast in early to '
#            'mid-July, applying 25% fluopicolide-tebuconazole 0.75-0.9L/ha or 45% tebuconazole 0.42-0.5L/ha, spraying '
#            'twice weekly. For neck blast, spray at the beginning and full heading stages. Use the same dosage as for '
#            'leaf blast.',
#  'image': '/dataset/images/Rice,Blast/plant_121715.jpg',
#  'question': 'What measures can be taken to control Rice Blast?',
#  'question_id': 'test_knowledge_conv_0001'}

# %% [markdown]
# ## Install Unsloth and Dependencies

# %%
# %%capture
import os, subprocess, sys, json, re, random, itertools, collections
import numpy as np
from pathlib import Path

if "COLAB_" in "".join(os.environ.keys()):
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 \
           peft trl triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf "datasets>=3.4.1,<4.0.0" \
           "huggingface_hub>=0.34.0" hf_transfer
    # !pip install --no-deps unsloth
else:
    # !pip install unsloth

# Latest Transformers + timm for Gemma-3N
# !pip install --no-deps --upgrade transformers timm

# %% [markdown]
# ## Load and Configure Model
# #### Load Gemma-3n-E2B-it base model

# %%
from unsloth import FastVisionModel, get_chat_template
import torch, gc

model, processor = FastVisionModel.from_pretrained(
    "unsloth/gemma-3n-E2B-it",   #  instruct-tuned
    dtype          = None,    # auto
    max_seq_length = 2048,
    load_in_4bit   = True,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.8.1: Fast Gemma3N patching. Transformers: 4.54.1.
#    \\   /|    NVIDIA L4. Num GPUs = 1. Max memory: 22.161 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 8.9. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: Gemma3N does not support SDPA - switching to eager!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/2.65G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/469M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/210 [00:00<?, ?B/s]
# processor_config.json:   0%|          | 0.00/98.0 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# preprocessor_config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.70M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/777 [00:00<?, ?B/s]

# %% [markdown]
# ### Configure LoRA fine-tuning

# %%
model = FastVisionModel.get_peft_model(
    model,
    finetune_vision_layers     = True,
    finetune_language_layers   = True,
    finetune_attention_modules = True,
    finetune_mlp_modules       = True,
    r              = 32,          #
    lora_alpha     = 32,
    lora_dropout   = 0.05,
    bias           = "none",
    random_state   = 3407,
    target_modules = "all-linear",
)
# Out:
# Unsloth: Dropout = 0 is supported for fast patching. You are using dropout = 0.05.
# Unsloth will patch all other layers, except LoRA matrices, causing a performance hit.
# Unsloth: Making `model.base_model.model.model.language_model` require gradients

# %% [markdown]
# ### Prepare Training Data

# %%
# ---------- paths ----------
IMG_ROOT = Path("dataset/images")                     # your image tree
TRAIN_JSON = Path("dataset/VQA/Crop_Disease_train_qwenvl.json")

# ---------- 3.1 collect images & stratified 8 k sample ----------
img_exts = {".jpg", ".jpeg", ".png", ".bmp", ".webp"}
all_imgs  = [p for p in IMG_ROOT.rglob("*") if p.suffix.lower() in img_exts]

# bucket by "Crop,Disease" folder
buckets = collections.defaultdict(list)
for p in all_imgs:
    buckets[p.parent.name].append(p)

# ── take ≤133 per disease so 60 diseases → ≈8 k
random.seed(42)
target_per_bucket = 150
sampled_imgs = []
for lst in buckets.values():
    k = min(len(lst), target_per_bucket)
    sampled_imgs.extend(random.sample(lst, k))

sampled_set = set(sampled_imgs)     # for O(1) lookup

print(f"Sampling → {len(sampled_set):,} images")
# Out:
# Sampling → 8,672 images

# %% [markdown]
# ### Extract Q&A pairs from JSON

# %%
# ---------- 3.2  •  parse JSON → (img, question, answer) tuples ----------

import json, re
from pathlib import Path
from PIL import Image

# 📝 1) Build a *string* set of the 7 720 sampled image paths
#      • all lowercase / forward-slash / no leading "/" → "dataset/images/…"
sampled_set = {p.as_posix().lstrip("/") for p in sampled_imgs}

def extract_pairs(record):
    """
    Yield tuples:
        (Path image_path, str question, str answer)
    Only keep images that are in our  subset.
    """
    conv = record["conversations"]
    for i in range(0, len(conv) - 1, 2):
        user, assistant = conv[i], conv[i + 1]
        if user["from"] != "user" or assistant["from"] != "assistant":
            continue

        # ---- pull the image tag ----
        m = re.search(r"<img>(.*?)</img>", user["value"])
        if not m:
            continue
        raw_path = m.group(1).lstrip("/")                # drop leading "/"
        if raw_path not in sampled_set:                  # keep only subset
            continue

        # ---- clean up Q & A ----
        question = re.sub(r"<img>.*?</img>", "", user["value"]).strip()
        answer   = assistant["value"].strip()

        yield Path(raw_path), question, answer


# ---------- run the extraction ----------
records = []
with TRAIN_JSON.open() as f:
    data = json.load(f)

for rec in data:
    records.extend(extract_pairs(rec))

print(f"Pairs kept: {len(records):,}")   #  should now be > 0,
# Out:
# Pairs kept: 9,970

# %% [markdown]
# ### Convert to Gemma-3n chat format

# %%
# ---------- 3.3 convert to UnsLoTH "messages" format ----------
def to_conversation(img_path, q, a):
    img = Image.open(img_path).convert("RGB")
    return {
        "messages": [
            {
                "role": "user",
                "content": [
                    {"type": "text",  "text": q},
                    {"type": "image", "image": img},
                ],
            },
            {
                "role": "assistant",
                "content": [{"type": "text", "text": a}],
            },
        ]
    }

converted_dataset = [to_conversation(*t) for t in records]
print("✅ dataset ready:", len(converted_dataset))
# Out:
# ✅ dataset ready: 9970

# %% [markdown]
# #### Apply Gemma-3n chat template

# %%
processor = get_chat_template(processor, "gemma-3n")   # in-place patch

# %% [markdown]
# ### Configure Weights & Biases

# %%
# 📌 1.  W&B login & project/run setup  ────────────────
import os, wandb
if wandb.api.api_key is None:
    wandb.login()                           # prompts once if needed

PROJECT_NAME = "Agri-gemma3n-finetune"
RUN_NAME     = "agri-gemma-3n-E2B-it"

os.environ["WANDB_PROJECT"] = PROJECT_NAME
wandb.init(project=PROJECT_NAME, name=RUN_NAME, reinit=True)

# 📌 2.  Trainer – 1-epoch run on  examples ─────────
from unsloth.trainer import UnslothVisionDataCollator
from trl import SFTTrainer, SFTConfig

trainer = SFTTrainer(
    model            = model,
    train_dataset    = converted_dataset,     # ~25 k items
    processing_class = processor.tokenizer,
    data_collator    = UnslothVisionDataCollator(model, processor),
    args = SFTConfig(
        # ── core hyper-params ──────────────────────────
        per_device_train_batch_size = 2,      # fits comfortably on an A100
        gradient_accumulation_steps = 4,      # ⇒ effective batch ≈ 8
        num_train_epochs            = 1,      # ← full pass over 20 k
        learning_rate               = 2e-4,
        warmup_ratio                = 0.03,
        max_grad_norm               = 0.3,
        logging_steps               = 20,
        save_strategy               = "epoch",
        optim                       = "adamw_torch_fused",
        weight_decay                = 0.01,
        lr_scheduler_type           = "cosine",
        seed                        = 3407,
        max_length                  = 2048,

        # ── W&B hook ──────────────────────────────────
        report_to                   = "wandb",
        run_name                    = RUN_NAME,

        # ── misc / vision flags ───────────────────────
        output_dir                  = "outputs_AgriGemma",
        remove_unused_columns       = False,
        dataset_text_field          = "",
        dataset_kwargs              = {"skip_prepare_dataset": True},
    ),
)
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: alfaxadeyembe (alfaxad) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href='https://wandb.me/wandb-init' target="_blank">the W&B docs</a>.
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/content/wandb/run-20250804_161917-8gmtisjp</code>
# Syncing run <strong><a href='https://wandb.ai/alfaxad/Agri-gemma3n-finetune/runs/8gmtisjp' target="_blank">agri-gemma-3n-E2B-it</a></strong> to <a href='https://wandb.ai/alfaxad/Agri-gemma3n-finetune' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/alfaxad/Agri-gemma3n-finetune' target="_blank">https://wandb.ai/alfaxad/Agri-gemma3n-finetune</a>
#  View run at <a href='https://wandb.ai/alfaxad/Agri-gemma3n-finetune/runs/8gmtisjp' target="_blank">https://wandb.ai/alfaxad/Agri-gemma3n-finetune/runs/8gmtisjp</a>
# Unsloth: Model does not have a default image size - using 512

# %% [markdown]
# ### Execute training

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 9,970 | Num Epochs = 1 | Total steps = 1,247
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 42,270,720 of 5,481,708,992 (0.77% trained)
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='1247' max='1247' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1247/1247 2:02:50, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>20</td>
#       <td>3.162500</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.424000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.094000</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.294700</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.943400</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.943700</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.872500</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.894900</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.794200</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.655100</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.633700</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.584800</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.800300</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.618200</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.410700</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.658900</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.600800</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.290400</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.577200</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.537700</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.296000</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.251700</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.298500</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.399500</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.306600</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.297700</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.438300</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.289300</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.261900</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.150200</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.187400</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>0.239000</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>0.152000</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>0.316100</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.192200</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>0.118500</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>0.173400</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>0.120500</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>0.179300</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.133100</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>0.129000</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>0.199800</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>0.177500</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>0.146200</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.160800</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>0.203100</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>0.140700</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>0.184400</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>0.134200</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.179200</td>
#     </tr>
#     <tr>
#       <td>1020</td>
#       <td>0.137600</td>
#     </tr>
#     <tr>
#       <td>1040</td>
#       <td>0.074000</td>
#     </tr>
#     <tr>
#       <td>1060</td>
#       <td>0.132900</td>
#     </tr>
#     <tr>
#       <td>1080</td>
#       <td>0.231100</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.196900</td>
#     </tr>
#     <tr>
#       <td>1120</td>
#       <td>0.119800</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>0.223600</td>
#     </tr>
#     <tr>
#       <td>1160</td>
#       <td>0.117200</td>
#     </tr>
#     <tr>
#       <td>1180</td>
#       <td>0.245200</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.072000</td>
#     </tr>
#     <tr>
#       <td>1220</td>
#       <td>0.060700</td>
#     </tr>
#     <tr>
#       <td>1240</td>
#       <td>0.142000</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# ## Test the Fine-tuned model

# %%
from PIL import Image
Image.open("/content/dataset/images/Tomato,Early Blight/plant_17947.jpg").convert("RGB")
# Out:
# <PIL.Image.Image image mode=RGB size=349x447>

# %%
FastVisionModel.for_inference(model)  # Enable for inference!


image = Image.open("/content/dataset/images/Tomato,Early Blight/plant_17947.jpg").convert("RGB")



instruction = "Identify the crop and describe the disease symptoms shown in this image."

# 3️⃣ Build a Gemma-3N multimodal chat message
messages = [
    {
        "role": "user",
        "content": [
            {"type": "image"},                     # placeholder only
            {"type": "text", "text": instruction},
        ],
    }
]

# 4️⃣ Convert to model input
input_text = processor.apply_chat_template(messages, add_generation_prompt=True)

inputs = processor(
    image,
    input_text,
    add_special_tokens=False,
    return_tensors="pt",
).to("cuda")

# 5️⃣ Generate
from transformers import TextStreamer
streamer = TextStreamer(processor, skip_prompt=True)

_ = model.generate(
    **inputs,
    max_new_tokens = 128,
    use_cache      = True,
    temperature    = 1.0,
    top_p          = 0.95,
    top_k          = 64,
    streamer       = streamer,
)
# Out:
# The crop is a tomato plant. The disease symptoms shown in the image are brown spots on the upper surface of the leaf, with yellow margins and necrotic tissue around the spots.<end_of_turn>

# %% [markdown]
# ## Save The LoRA Updates, Save The Model In Various Formats And Push it To HuggingFace

# %%
model.save_pretrained("agri-gemma-3n-e2b-lora")  # Local saving
processor.save_pretrained("agri-gemma-3n-e2b-lora")
# model.push_to_hub("your_name/lora_model", token = "...") # Online saving
# processor.push_to_hub("your_name/lora_model", token = "...") # Online saving
# Out:
# ['agri-gemma-3n-e2b-lora/processor_config.json']

# %%
if True: # Change to True to save finetune!
    model.save_pretrained_merged("AgriGemma-3n-E2B-it", processor)
# Out:
# Found HuggingFace hub cache directory: /root/.cache/huggingface/hub
# Checking cache directory for required files...
# Cache check failed: model-00001-of-00003.safetensors not found in local cache.
# Not all required files found in cache. Will proceed with downloading.
# Downloading safetensors index for unsloth/gemma-3n-e2b-it...
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Unsloth: Merging weights into 16bit:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/3.08G [00:00<?, ?B/s]
# Unsloth: Merging weights into 16bit:  33%|███▎      | 1/3 [00:17<00:35, 17.91s/it]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# Unsloth: Merging weights into 16bit:  67%|██████▋   | 2/3 [00:56<00:29, 29.79s/it]
# model-00003-of-00003.safetensors:   0%|          | 0.00/2.82G [00:00<?, ?B/s]
# Unsloth: Merging weights into 16bit: 100%|██████████| 3/3 [01:18<00:00, 26.03s/it]

# %%
if True: # Change to True to upload finetune
    model.push_to_hub_merged(
        "Account/AgriGemma-3n-E2B-it", processor,
        token = "hf"
    )
# Out:
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   .../AgriGemma-3n-E2B-it/tokenizer.json:  75%|#######5  | 25.1MB / 33.4MB
#   ...AgriGemma-3n-E2B-it/tokenizer.model: 100%|##########| 4.70MB / 4.70MB
# Found HuggingFace hub cache directory: /root/.cache/huggingface/hub
# Checking cache directory for required files...
# Cache check failed: model-00001-of-00003.safetensors not found in local cache.
# Not all required files found in cache. Will proceed with downloading.
# Downloading safetensors index for unsloth/gemma-3n-e2b-it...
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Unsloth: Merging weights into 16bit:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/3.08G [00:00<?, ?B/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   ...it/model-00001-of-00003.safetensors:   1%|1         | 41.8MB / 3.08GB
# Unsloth: Merging weights into 16bit:  33%|███▎      | 1/3 [02:08<04:16, 128.37s/it]
# model-00002-of-00003.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   ...it/model-00002-of-00003.safetensors:   1%|          | 25.1MB / 4.98GB
# Unsloth: Merging weights into 16bit:  67%|██████▋   | 2/3 [07:05<03:47, 227.36s/it]
# model-00003-of-00003.safetensors:   0%|          | 0.00/2.82G [00:00<?, ?B/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   ...it/model-00003-of-00003.safetensors:   0%|          | 1.99MB / 2.82GB
# Unsloth: Merging weights into 16bit: 100%|██████████| 3/3 [10:34<00:00, 211.52s/it]

# %%
if True: # Change to True to save to GGUF
    model.save_pretrained_gguf(
        "AgriGemma-3n-E2B-it",
        quantization_type = "Q8_0", # For now only Q8_0, BF16, F16 supported
    )
# Out:
# Unsloth: Updating system package directories
# Unsloth: Install GGUF and other packages
# Unsloth GGUF:hf-to-gguf:Loading model: AgriGemma-3n-E2B-it
# Unsloth GGUF:hf-to-gguf:Model architecture: Gemma3nForConditionalGeneration
# Unsloth GGUF:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# Unsloth GGUF:hf-to-gguf:Exporting model...
# Unsloth GGUF:hf-to-gguf:gguf: loading model weight map from 'model.safetensors.index.json'
# Unsloth GGUF:hf-to-gguf:gguf: loading model part 'model-00001-of-00003.safetensors'
# Unsloth GGUF:hf-to-gguf:altup_proj.weight,                 torch.bfloat16 --> Q8_0, shape = {2048, 2048, 3}
# Unsloth GGUF:hf-to-gguf:altup_unembd_proj.weight,          torch.bfloat16 --> Q8_0, shape = {2048, 2048, 3}
# Unsloth GGUF:hf-to-gguf:token_embd.weight,                 torch.bfloat16 --> Q8_0, shape = {2048, 262144}
# Unsloth GGUF:hf-to-gguf:gguf: loading model part 'model-00002-of-00003.safetensors'
# Unsloth GGUF:hf-to-gguf:per_layer_token_embd.weight,       torch.bfloat16 --> Q8_0, shape = {7680, 262144}
# Unsloth GGUF:hf-to-gguf:output_norm.weight,                torch.bfloat16 --> F32, shape = {2048}
# Unsloth GGUF:hf-to-gguf:per_layer_model_proj.weight,       torch.bfloat16 --> Q8_0, shape = {2048, 7680}
# Unsloth GGUF:hf-to-gguf:per_layer_proj_norm.weight,        torch.bfloat16 --> F32, shape = {256}
# Unsloth GGUF:hf-to-gguf:gguf: loading model part 'model-00003-of-00003.safetensors'
# Unsloth GGUF:hf-to-gguf:Set meta model
# Unsloth GGUF:hf-to-gguf:Set model parameters
# Unsloth GGUF:hf-to-gguf:Set model quantization version
# Unsloth GGUF:hf-to-gguf:Set model tokenizer
# Unsloth GGUF:gguf.vocab:Setting special token type bos to 2
# Unsloth GGUF:gguf.vocab:Setting special token type eos to 106
# Unsloth GGUF:gguf.vocab:Setting special token type unk to 3
# Unsloth GGUF:gguf.vocab:Setting special token type pad to 0
# Unsloth GGUF:gguf.vocab:Setting add_bos_token to True
# Unsloth GGUF:gguf.vocab:Setting add_sep_token to False
# Unsloth GGUF:gguf.vocab:Setting add_eos_token to False
# Unsloth GGUF:gguf.vocab:Setting chat_template to {{ bos_token }}
# {%- if messages[0]['role'] == 'system' -%}
#     {%- if messages[0]['content'] is string -%}
#         {%- set first_user_prefix = messages[0]['content'] + '
#
# ' -%}
#     {%- else -%}
#         {%- set first_user_prefix = messages[0]['content'][0]['text'] + '
# ..... Chat template truncated .....
# Unsloth: GGUF conversion:   0%|          | 0/100 [00:00<?, ?it/s]
# Unsloth GGUF:hf-to-gguf:Model successfully exported to ./
# Unsloth: Converted to AgriGemma-3n-E2B-it.Q8_0.gguf with size = 4.7G
# Unsloth: Successfully saved GGUF to:
# AgriGemma-3n-E2B-it.Q8_0.gguf

# %%
if True: # Change to True to upload GGUF
    model.push_to_hub_gguf(
        "AgriGemma-3n-E2B-it",
        quantization_type = "Q8_0", # Only Q8_0, BF16, F16 supported
        repo_id = "Nadhari/AgriGemma-3n-E2B-it-gguf",
        token = "hf",
    )
# Out:
# Unsloth GGUF:hf-to-gguf:Loading model: AgriGemma-3n-E2B-it
# Unsloth GGUF:hf-to-gguf:Model architecture: Gemma3nForConditionalGeneration
# Unsloth GGUF:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# Unsloth GGUF:hf-to-gguf:Exporting model...
# Unsloth GGUF:hf-to-gguf:gguf: loading model weight map from 'model.safetensors.index.json'
# Unsloth GGUF:hf-to-gguf:gguf: loading model part 'model-00001-of-00003.safetensors'
# Unsloth GGUF:hf-to-gguf:altup_proj.weight,                 torch.bfloat16 --> Q8_0, shape = {2048, 2048, 3}
# Unsloth GGUF:hf-to-gguf:altup_unembd_proj.weight,          torch.bfloat16 --> Q8_0, shape = {2048, 2048, 3}
# Unsloth GGUF:hf-to-gguf:token_embd.weight,                 torch.bfloat16 --> Q8_0, shape = {2048, 262144}
# Unsloth GGUF:hf-to-gguf:gguf: loading model part 'model-00002-of-00003.safetensors'
# Unsloth GGUF:hf-to-gguf:per_layer_token_embd.weight,       torch.bfloat16 --> Q8_0, shape = {7680, 262144}
# Unsloth GGUF:hf-to-gguf:output_norm.weight,                torch.bfloat16 --> F32, shape = {2048}
# Unsloth GGUF:hf-to-gguf:per_layer_model_proj.weight,       torch.bfloat16 --> Q8_0, shape = {2048, 7680}
# Unsloth GGUF:hf-to-gguf:per_layer_proj_norm.weight,        torch.bfloat16 --> F32, shape = {256}
# Unsloth GGUF:hf-to-gguf:gguf: loading model part 'model-00003-of-00003.safetensors'
# Unsloth GGUF:hf-to-gguf:Set meta model
# Unsloth GGUF:hf-to-gguf:Set model parameters
# Unsloth GGUF:hf-to-gguf:Set model quantization version
# Unsloth GGUF:hf-to-gguf:Set model tokenizer
# Unsloth GGUF:gguf.vocab:Setting special token type bos to 2
# Unsloth GGUF:gguf.vocab:Setting special token type eos to 106
# Unsloth GGUF:gguf.vocab:Setting special token type unk to 3
# Unsloth GGUF:gguf.vocab:Setting special token type pad to 0
# Unsloth GGUF:gguf.vocab:Setting add_bos_token to True
# Unsloth GGUF:gguf.vocab:Setting add_sep_token to False
# Unsloth GGUF:gguf.vocab:Setting add_eos_token to False
# Unsloth GGUF:gguf.vocab:Setting chat_template to {{ bos_token }}
# {%- if messages[0]['role'] == 'system' -%}
#     {%- if messages[0]['content'] is string -%}
#         {%- set first_user_prefix = messages[0]['content'] + '
#
# ' -%}
#     {%- else -%}
#         {%- set first_user_prefix = messages[0]['content'][0]['text'] + '
# ..... Chat template truncated .....
# Unsloth: GGUF conversion:   0%|          | 0/100 [00:00<?, ?it/s]
# Unsloth GGUF:hf-to-gguf:Model successfully exported to ./
# Unsloth: Converted to AgriGemma-3n-E2B-it.Q8_0.gguf with size = 4.7G
# Unsloth: Successfully saved GGUF to:
# AgriGemma-3n-E2B-it.Q8_0.gguf
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.
# No files have been modified since last commit. Skipping to prevent empty commit.
# WARNING:huggingface_hub.hf_api:No files have been modified since last commit. Skipping to prevent empty commit.

# %%
from huggingface_hub import HfApi

api = HfApi()
api.upload_file(
    path_or_fileobj="AgriGemma-3n-E2B-it.Q8_0.gguf",
    path_in_repo="AgriGemma-3n-E2B-it.Q8_0.gguf",
    repo_id="Nadhari/AgriGemma-3n-E2B-it-gguf",
    token="hf"
)
# Out:
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
# New Data Upload                         : |          |  0.00B /  0.00B
#   AgriGemma-3n-E2B-it.Q8_0.gguf         :   1%|          | 42.0MB / 4.74GB
# CommitInfo(commit_url='https://huggingface.co/Nadhari/AgriGemma-3n-E2B-it-gguf/commit/b3671f2bb6f2fe3e018ba6df224f6896b514d993', commit_message='Upload AgriGemma-3n-E2B-it.Q8_0.gguf with huggingface_hub', commit_description='', oid='b3671f2bb6f2fe3e018ba6df224f6896b514d993', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Nadhari/AgriGemma-3n-E2B-it-gguf', endpoint='https://huggingface.co', repo_type='model', repo_id='Nadhari/AgriGemma-3n-E2B-it-gguf'), pr_revision=None, pr_num=None)
